# %%
import io
import json
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, GRU, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv("/kaggle/input/language-detection/Language Detection.csv")
df = df.sample(frac=1)

# %%
df.head()
# Out:
#                                                    Text   Language
# 7708                        sei libero sabato prossimo?    Italian
# 6111  Первые 5 разделов в это время имели следующий ...    Russian
# 3679  À partir de l'été 2002, tous les sites sont pr...     French
# 1504  വിക്കിപീഡിയയിൽ രജിസ്റ്റർ ചെയ്യുന്നതിലൂടെയാണ് വ...  Malayalam
# 7993  İngilizce konuşulan bir ülkeye, bunu tamamen k...    Turkish

# %%
df['Language'].value_counts()
# Out:
# Language
# English       1385
# French        1014
# Spanish        819
# Portugeese     739
# Italian        698
# Russian        692
# Sweedish       676
# Malayalam      594
# Dutch          546
# Arabic         536
# Turkish        474
# German         470
# Tamil          469
# Danish         428
# Kannada        369
# Greek          365
# Hindi           63
# Name: count, dtype: int64

# %%
df['Text Length'] = df['Text'].apply(len)

# %%
df['Text Length'].describe()
# Out:
# count    10337.000000
# mean       124.055625
# std        253.688194
# min          1.000000
# 25%         43.000000
# 50%        100.000000
# 75%        166.000000
# max      19088.000000
# Name: Text Length, dtype: float64

# %%
df.sort_values(by='Text Length', ascending=False).head(20)
# Out:
#                                                    Text    Language  \
# 1997  तब से विकिमीडिया ने कई अन्य परियोजनाएं शुरू की...       Hindi
# 1979  विकि-शब्दकोष (एक मुक्त शब्दकोष एवं समानांतर को...       Hindi
# 2041  एक सेकंड पर लटकाओ। बस एक पल मेरे साथ सहन करो। ...       Hindi
# 1984  वह टिप्पणी देते हैं कि नॉन-फिक्शन के कई पारंपर...       Hindi
# 1988  के कोरियाई होस्टिंग सुविधा सियोल में थीं।[104]...       Hindi
# 1996  पहले से ही, राष्ट्रपति प्रविष्टियों को प्रतिदि...       Hindi
# 2012  नहीं, आपने एक अद्भुत काम किया है। यदि आप किसी ...       Hindi
# 1981  बोट्स नामक कंप्यूटर प्रोग्राम के निर्माण के बा...       Hindi
# 2005  अगर आप किसी से पूछते हैं कि आप रोने के लिए परे...       Hindi
# 2889  [220][221][222] O MediaWiki tem documentação s...  Portugeese
# 1992  [137] विकिपीडिया के अवयवों को अकादमिक अध्ययन, ...       Hindi
# 1985  यह परियोजना के बारे में बार बार, अक्सर अन्य वे...       Hindi
# 1986  विद्यार्थी आंद्रे सिफोलिली ने तर्क दिया कि विक...       Hindi
# 1991  शेष के लिए, विशेष भाषा से सम्बंधित लेख के लिए ...       Hindi
# 1987  मीड़याविकी को GNU जनरल पब्लिक लाइसेंस के तहत ल...       Hindi
# 1995  इस दुनिया में कोई भी किसी भी विषय के बारे में ...       Hindi
# 1990  [115] चूंकि विकिपीडिया वेब आधारित है और इसलिए ...       Hindi
# 2002  अच्छी तरह से आप बस जवाब दे सकते हैं कि सब कुछ ...       Hindi
# 1980  [42] अंत में, विकिपीडिया एक पक्ष नहीं लेता है।...       Hindi
# 3858  Ces programmes, selon leur degré de perfection...      French
#
#       Text Length
# 1997        19088
# 1979         8752
# 2041         8019
# 1984         4068
# 1988         3678
# 1996         3093
# 2012         2849
# 1981         2750
# 2005         2236
# 2889         1965
# 1992         1846
# 1985         1651
# 1986         1631
# 1991         1533
# 1987         1421
# 1995         1385
# 1990         1379
# 2002         1374
# 1980         1310
# 3858         1168

# %%
df.drop(index=df[df['Language'] == 'Hindi'].index, inplace=True)

# %%
train_ratio = 0.8
val_ratio = 0.2

train = df.iloc[:int(len(df) * 0.8)]
val = df.iloc[int(len(df) * 0.8):]

assert(len(train) + len(val) == len(df))
len(train), len(val)
# Out:
# (8219, 2055)

# %%
tokenizer = Tokenizer(oov_token='<UNK>', filters='"#$%&()*+-/:;=@[\\]^_`{|}~\t\n0123456789')

# %%
train_sentences = list(train['Text'].values)
val_sentences = list(val['Text'].values)

# %%
tokenizer.fit_on_texts(train_sentences)

# %%
tokenizer_json = tokenizer.to_json()
with io.open('general_tokenizer.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_json, ensure_ascii=False))

# %%
VOCAB_SIZE = len(tokenizer.word_index) + 1

# %%
train_sequences = tokenizer.texts_to_sequences(train_sentences)
val_sequences = tokenizer.texts_to_sequences(val_sentences)

# %%
MAX_LENGTH = int(df['Text'].apply(lambda x: len(x.split())).quantile(.95))

# %%
train_inputs = pad_sequences(train_sequences, maxlen=MAX_LENGTH, padding='post', truncating='post')
val_inputs = pad_sequences(val_sequences, maxlen=MAX_LENGTH, padding='post', truncating='post')

# %%
languages = df['Language'].unique()
d = {lang: i for i, lang in enumerate(languages)}

# %%
train_integer_encoded = [d[lang] for lang in train['Language']]
train_outputs = tf.keras.utils.to_categorical(train_integer_encoded, num_classes=len(languages))
val_integer_encoded = [d[lang] for lang in val['Language']]
val_outputs = tf.keras.utils.to_categorical(val_integer_encoded, num_classes=len(languages))

# %%
model = Sequential([
    Embedding(input_dim=VOCAB_SIZE, output_dim=64, input_length=MAX_LENGTH),
    Bidirectional(GRU(units=32, dropout=0.3)),
    Dense(16, activation='softmax')
])

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics='accuracy')

# %%
history = model.fit(train_inputs, 
                    train_outputs, 
                    validation_data=(val_inputs, val_outputs),
                    epochs=15,
                    batch_size=50)
# Out:
# Epoch 1/15
# 165/165 [==============================] - 18s 81ms/step - loss: 2.2877 - accuracy: 0.2778 - val_loss: 1.5590 - val_accuracy: 0.5825
# Epoch 2/15
# 165/165 [==============================] - 11s 69ms/step - loss: 1.0432 - accuracy: 0.7602 - val_loss: 0.8227 - val_accuracy: 0.8380
# Epoch 3/15
# 165/165 [==============================] - 11s 67ms/step - loss: 0.4259 - accuracy: 0.9435 - val_loss: 0.4189 - val_accuracy: 0.9153
# Epoch 4/15
# 165/165 [==============================] - 11s 68ms/step - loss: 0.1654 - accuracy: 0.9808 - val_loss: 0.3109 - val_accuracy: 0.9270
# Epoch 5/15
# 165/165 [==============================] - 11s 67ms/step - loss: 0.0779 - accuracy: 0.9937 - val_loss: 0.3095 - val_accuracy: 0.9236
# Epoch 6/15
# 165/165 [==============================] - 11s 67ms/step - loss: 0.0431 - accuracy: 0.9979 - val_loss: 0.2669 - val_accuracy: 0.9333
# Epoch 7/15
# 165/165 [==============================] - 11s 66ms/step - loss: 0.0263 - accuracy: 0.9993 - val_loss: 0.2767 - val_accuracy: 0.9314
# Epoch 8/15
# 165/165 [==============================] - 11s 66ms/step - loss: 0.0182 - accuracy: 0.9993 - val_loss: 0.2682 - val_accuracy: 0.9333
# Epoch 9/15
# 165/165 [==============================] - 11s 70ms/step - loss: 0.0130 - accuracy: 0.9994 - val_loss: 0.2727 - val_accuracy: 0.9338
# Epoch 10/15
# 165/165 [==============================] - 11s 66ms/step - loss: 0.0099 - accuracy: 0.9991 - val_loss: 0.3051 - val_accuracy: 0.9231
# Epoch 11/15
# 165/165 [==============================] - 11s 67ms/step - loss: 0.0066 - accuracy: 0.9995 - val_loss: 0.2685 - val_accuracy: 0.9290
# Epoch 12/15
# 165/165 [==============================] - 11s 69ms/step - loss: 0.0054 - accuracy: 0.9995 - val_loss: 0.2457 - val_accuracy: 0.9367
# Epoch 13/15
# 165/165 [==============================] - 11s 66ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 0.2718 - val_accuracy: 0.9309
# Epoch 14/15
# 165/165 [==============================] - 11s 67ms/step - loss: 0.0040 - accuracy: 0.9998 - val_loss: 0.2501 - val_accuracy: 0.9401
# Epoch 15/15
# 165/165 [==============================] - 11s 68ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.2727 - val_accuracy: 0.9324

# %%
model.save('language-detection-model')
# !zip -r ./language-detection-model.zip ./language-detection-model
# Out:
#   adding: language-detection-model/ (stored 0%)
#   adding: language-detection-model/variables/ (stored 0%)
#   adding: language-detection-model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: language-detection-model/variables/variables.index (deflated 63%)
#   adding: language-detection-model/saved_model.pb (deflated 90%)
#   adding: language-detection-model/fingerprint.pb (stored 0%)
#   adding: language-detection-model/assets/ (stored 0%)
#   adding: language-detection-model/keras_metadata.pb (deflated 89%)
